# %%
from sklearn.datasets import make_regression
import pandas as pd
import numpy as np

import plotly.express as px
import plotly.graph_objects as go

from sklearn.metrics import mean_absolute_error,mean_squared_error,r2_score

# %%
X,y = make_regression(n_samples=100, n_features=2, n_informative=2, n_targets=1, noise=50)

# %%
df = pd.DataFrame({'feature1':X[:,0],'feature2':X[:,1],'target':y})

# %%
df.shape
# Out:
# (100, 3)

# %%
df.head()
# Out:
#    feature1  feature2      target
# 0  0.924124  1.487474   32.680979
# 1 -0.697663  0.038495  -40.440956
# 2  1.889465  1.747887  174.829195
# 3  0.085294  1.899630    5.635822
# 4  2.319086  1.301755  251.437905

# %%
fig = px.scatter_3d(df, x='feature1', y='feature2', z='target')

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="1df5a7f4-ee5e-4a14-90c4-71386a8f28d8" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("1df5a7f4-ee5e-4a14-90c4-71386a8f28d8")) {                    Plotly.newPlot(                        "1df5a7f4-ee5e-4a14-90c4-71386a8f28d8",                        [{"hovertemplate":"feature1=%{x}\u003cbr\u003efeature2=%{y}\u003cbr\u003etarget=%{z}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","scene":"scene","showlegend":false,"x":[0.9241238656067688,-0.6976627217696285,1.8894650343358024,0.0852938729372975,2.319085584934764,0.2857406857356433,0.04948224410887602,-0.2552498570321684,-0.8594778655667614,-0.960701076694606,-0.24646906421214243,2.1023105602695087,-0.08986585874815688,-0.4653928516686255,0.021792388330934782,-1.1260437168927018,-0.30261472004964163,0.5057826253136212,-1.1152088232360329,-0.7277288791160078,1.610473777237194,0.5659323167691588,-0.35849609981751435,-0.29907045577116087,-0.16326391510905297,0.6215387373302531,0.2640844968808845,-0.5774907293085407,0.581720204744626,-0.46079469271579293,-0.710213126274002,1.4444573933523186,0.9252147417062195,0.42861475335861404,1.5433198787903337,-0.3031403295048937,2.3137378386845064,-1.0549394262326073,-1.824033821929937,-0.6161336735957461,-2.5950387643545376,0.05676719055208719,0.6402010911240358,-0.6364853608855837,1.5004376340043368,-0.0011493674269840457,-1.0111517777584997,-1.874889620872331,-0.725848534606881,0.43656508980246994,-0.02235353749112166,0.11713311848212671,-0.7789829413141353,-0.6829854189276631,0.8575228110226479,-0.2409178914217914,-0.022104984377426962,1.0490488880932796,-0.9803025506240902,0.8009553312364202,0.19249599075951224,0.03035973736551679,-0.9401964671893824,0.7411825203338025,-0.9447378315329007,-1.0016094050683972,-1.9050267855986662,2.1825114939158503,1.3026383710620353,-0.9112635287871533,0.4273223289023012,-1.1265950381873153,0.013561038327665547,-0.6511477432112887,-1.8701774603137953,-1.5658405620557831,0.11848802095751529,1.692178034924134,0.40156797883267326,0.03657980733155034,-0.4983550478478469,1.3448274248915326,-0.39934064553545895,-0.2678355805565247,0.8897902277348355,-0.1793339008013273,-0.9233830680975895,-2.5908418866288088,0.6154599058365218,-0.2797849385157784,-1.7043772175336889,1.830703886606596,-0.7267887978936922,0.889655817307425,-0.5040730689141691,0.39433981156503733,-0.38897779399944815,1.6300258840567199,0.36006776612456143,-0.668578004720217],"y":[1.487473814711814,0.03849476173461953,1.7478866260087862,1.8996300343098507,1.3017554015548114,-1.0860986821874083,0.980511470604665,0.7921747801322006,-0.36629926902672727,-0.4309420418567815,-0.6204767242748741,0.5959967652414896,-1.1342092059123845,-0.9600637620173378,0.8136349276686619,2.20901660874781,-0.9725367512239507,1.4194770740246927,-0.8068190510054981,-0.2659616090144196,0.9051672524524711,0.14552337134646473,0.8785561058329023,-1.1317346215505086,1.0652776376638877,0.5333747550373512,0.6424478390987948,-0.41931471788074504,1.7574193592074654,0.007825634774454334,0.8189561645483246,-0.5967734062173509,0.8152279379578168,-0.35568758808864964,0.3823438387646249,-0.09191986724528636,-0.07286210913572796,0.37153053520330076,-0.6895557026517202,1.3685398400865771,0.9881055978252002,0.06439872349591289,-0.731354493956061,-0.10451786146947611,-0.8778449342367184,-1.4988104583716553,-0.3238127650056884,-0.4695096160429192,-0.2689869772160811,-0.5289623418010535,0.4020662273190259,-0.7394711712442898,-1.1377629679535666,-1.0360319310195403,-1.299846424921679,-1.105649687467572,-0.36075011704542165,0.7307198546859628,-0.4355433996042295,-0.08068615926791751,1.1185175332270363,0.4 ...

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=3)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(X_test)

# %%
print("MAE",mean_absolute_error(y_test,y_pred))
print("MSE",mean_squared_error(y_test,y_pred))
print("R2 score",r2_score(y_test,y_pred))
# Out:
# MAE 42.425502390119625
# MSE 2824.5568023780484
# R2 score 0.7294123862687764

# %%
x = np.linspace(-5, 5, 10)
y = np.linspace(-5, 5, 10)
xGrid, yGrid = np.meshgrid(y, x)
final = np.vstack((xGrid.ravel().reshape(1,100),yGrid.ravel().reshape(1,100))).T

z_final = lr.predict(final).reshape(10,10)

z = z_final
z_final = lr.predict(final).reshape(10,10)

# %%
lr.coef_
# Out:
# array([81.39229492, -0.56596509])

# %%
lr.intercept_
# Out:
# np.float64(4.075563813501535)
