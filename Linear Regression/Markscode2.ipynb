# %%
class MeraLR:

    def __init__(self):
        self.m = None
        self.b = None

    def fit(self,X_train,y_train):

        num = 0
        den = 0

        for i in range(X_train.shape[0]):

            num = num + ((X_train[i] - X_train.mean())*(y_train[i] - y_train.mean()))
            den = den + ((X_train[i] - X_train.mean())*(X_train[i] - X_train.mean()))

        self.m = num/den
        self.b = y_train.mean() - (self.m * X_train.mean())
        print(self.m)
        print(self.b)

    def predict(self,X_test):

        # print(X_test)

        return self.m * X_test + self.b

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv('JEE.csv')

# %%
df.head()
# Out:
#    12th_Marks  JEE_Percentile
# 0          96           88.04
# 1         100           58.54
# 2          62           91.12
# 3          74           66.92
# 4          62           60.68

# %%
df.head()
X = df.iloc[:,0].values
y = df.iloc[:,1].values

# %%
X
# Out:
# array([ 96, 100,  62,  74,  62,  95, 100,  92,  73,  70,  68,  62,  64,
#         90,  70,  98,  92,  92,  80,  85,  98,  92,  77,  82,  78,  62,
#         99,  85,  89,  93,  83,  81,  96,  62,  97,  70,  73,  86,  71,
#         98,  62,  99,  96,  76,  65,  85,  76,  95,  83,  83,  88, 100,
#         99,  75,  77,  93,  85,  66,  85,  72,  71,  79,  69,  78,  97,
#         98,  61,  90,  85,  65,  77,  80,  95,  71,  60,  95,  91,  92,
#         76,  72,  79,  62,  96,  64,  79,  90,  78,  67,  66,  64,  61,
#         72,  71,  88,  73,  66,  75,  94,  61,  71])

# %%
y
# Out:
# array([88.04, 58.54, 91.12, 66.92, 60.68, 53.28, 85.23, 73.84, 59.08,
#        99.86, 52.43, 87.87, 97.24, 80.48, 95.89, 85.84, 93.54, 98.6 ,
#        89.82, 83.14, 67.06, 85.39, 58.06, 66.29, 90.96, 56.09, 95.88,
#        77.55, 75.41, 57.75, 63.7 , 54.24, 90.  , 99.73, 85.19, 52.12,
#        89.12, 57.68, 99.4 , 55.85, 57.31, 97.11, 75.14, 86.41, 96.38,
#        71.78, 57.24, 72.94, 94.65, 68.89, 67.12, 90.24, 89.23, 70.05,
#        62.99, 64.15, 83.78, 73.76, 76.8 , 79.92, 86.81, 82.65, 72.31,
#        74.88, 83.79, 82.95, 63.1 , 57.64, 85.6 , 56.66, 72.31, 77.05,
#        82.79, 57.07, 80.35, 62.54, 82.7 , 84.34, 54.31, 98.61, 78.66,
#        94.58, 83.16, 92.67, 90.64, 67.21, 69.47, 76.4 , 52.09, 76.87,
#        98.42, 60.52, 93.65, 81.19, 59.82, 59.13, 77.91, 86.03, 52.39,
#        93.98])

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_train.shape
# Out:
# (80,)

# %%
lr = MeraLR()

# %%
lr.fit(X_train,y_train)
# Out:
# 0.1599702122366448
# 62.13051435096811

# %%
X_train.shape[0]
# Out:
# 80

# %%
X_train[0]
# Out:
# np.int64(70)

# %%
X_train.mean()
# Out:
# np.float64(80.2125)

# %%
X_test[0]
# Out:
# np.int64(64)

# %%
print(lr.predict(X_test[0]))
# Out:
# 72.36860793411338
