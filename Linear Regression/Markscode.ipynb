# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('JEE.csv')

# %%
df.head()
# Out:
#    12th_Marks  JEE_Percentile
# 0          96           88.04
# 1         100           58.54
# 2          62           91.12
# 3          74           66.92
# 4          62           60.68

# %%
plt.scatter(df['12th_Marks'],df['JEE_Percentile'])
plt.xlabel('12th_Marks')
plt.ylabel('JEE_percentile')
# Out:
# Text(0, 0.5, 'JEE_percentile')

# %%
X = df.iloc[:,0:1]
y = df.iloc[:,-1]

# %%
X
# Out:
#     12th_Marks
# 0           96
# 1          100
# 2           62
# 3           74
# 4           62
# ..         ...
# 95          66
# 96          75
# 97          94
# 98          61
# 99          71
#
# [100 rows x 1 columns]

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.2,random_state=2)

# %%
X_test
# Out:
#     12th_Marks
# 83          64
# 30          83
# 56          85
# 24          78
# 16          92
# 23          82
# 2           62
# 27          85
# 28          89
# 13          90
# 99          71
# 92          71
# 76          91
# 14          70
# 0           96
# 21          92
# 3           74
# 29          93
# 61          79
# 79          72

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
X_test
# Out:
#     12th_Marks
# 83          64
# 30          83
# 56          85
# 24          78
# 16          92
# 23          82
# 2           62
# 27          85
# 28          89
# 13          90
# 99          71
# 92          71
# 76          91
# 14          70
# 0           96
# 21          92
# 3           74
# 29          93
# 61          79
# 79          72

# %%
y_test
# Out:
# 83    92.67
# 30    63.70
# 56    83.78
# 24    90.96
# 16    93.54
# 23    66.29
# 2     91.12
# 27    77.55
# 28    75.41
# 13    80.48
# 99    93.98
# 92    93.65
# 76    82.70
# 14    95.89
# 0     88.04
# 21    85.39
# 3     66.92
# 29    57.75
# 61    82.65
# 79    98.61
# Name: JEE_Percentile, dtype: float64

# %%
lr.predict(X_test.iloc[0].values.reshape(1,1))
# Out:
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([72.36860793])

# %%
plt.scatter(df['12th_Marks'],df['JEE_Percentile'])
plt.plot(X_train,lr.predict(X_train),color='red')
plt.xlabel('12th_Marks')
plt.ylabel('JEE_Percentile)')
# Out:
# Text(0, 0.5, 'JEE_Percentile)')

# %%
m = lr.coef_
m
# Out:
# array([0.15997021])

# %%
b = lr.intercept_
b
# Out:
# np.float64(62.130514350968106)

# %%
# y = mx + b

m * 8.58 + b
# Out:
# array([63.50305877])

# %%
m * 9.5 + b
# Out:
# array([63.65023137])

# %%
m * 100 + b
# Out:
# array([78.12753557])
